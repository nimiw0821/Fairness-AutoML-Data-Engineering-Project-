# %% [markdown]
# # This is the demo to apply our AutoML system to AdultDataset

# %% [markdown]
# ## dataset_metric you can select and their ranges
# 'mean_difference': [-1,1] close to 0 <br>
# 'statistical_parity_difference': [-1,1] close to 0 <br>
# 'disparate_impact': > 0  The larger the better<br>
# 'consistency': [0, 1]: The larger the better

# %% [markdown]
# ## classifier_metric (optimal range)
# "Statistical parity difference" : [-0.1, 0.1]<br>
# "Mean difference": [-0.1, 0.1] <br>
# "Disparate impact": [0.8,1.2] <br>
# "Average odds difference" [-0.1, 0.1] <br>
# "Equal opportunity difference" [-0.1, 0.1] <br>
# "Theil index": [0, 0.2]

# %%
import warnings
warnings.filterwarnings('ignore')
import AutoML
import pandas as pd
import numpy as np
from importlib import reload
pd.set_option('display.max_columns', None)
reload(AutoML)
import matplotlib.pyplot as plt
# %matplotlib inline
from aif360.algorithms.preprocessing.optim_preproc_helpers.distortion_functions\
            import get_distortion_adult
from aif360.algorithms.preprocessing.optim_preproc_helpers.data_preproc_functions import load_preproc_data_adult


df = load_preproc_data_adult()
train, test = df.split([0.5], shuffle=True)

privileged_groups = [{'race': 1}] # White
unprivileged_groups = [{'race': 0}] # Not white
optim_options = {
    "distortion_fun": get_distortion_adult,
    "epsilon": 0.05,
    "clist": [0.99, 1.99, 2.99],
    "dlist": [.1, 0.05, 0]
}

model = AutoML.FairAutoML(input_columns = train.feature_names, label_name = train.label_names, \
                          favorable_classes = [train.favorable_label], \
                          protected_attribute_names = train.protected_attribute_names, \
                          privileged_classes = train.privileged_protected_attributes, privileged_groups = privileged_groups, \
                          unprivileged_groups =  unprivileged_groups, is_valid = True)
model.fit(train, dataset_metric="disparate_impact", dataset_metric_threshold=0.9,
            classifier_metric="Disparate impact", optim_options = optim_options,
            time_left_for_this_task=200, per_run_time_limit=20, train_split_size=0.8,
            verbose=True)
# Out:
# #### Original training dataset
# Disparate impact (probability of favorable outcome for unprivileged instances / probability of favorable outcome for privileged instances) = 0.621812
# No discrimination potential, no need for fairness preprocessing:  False
# --------------Start Preprocessing--------------
# 25250 17561.714261620935
# 25500 11440.978660687239
# 25750 10460.363677489726
# 26000 10192.487502786633
# 26250 9770.490491875467
# 26500 9505.24288123524
# 26750 9620.907293638937
# 27000 9346.550268160914
# 27250 9204.965632306366
# 27500 9156.615210700942
# 27750 8925.728529573118
# 28000 8769.253184605977
# 28250 8750.114597049585
# 28500 8734.886498173058
# 28750 8723.703361005968
# 29000 8710.03283476395
# 29250 8938.09272034944
# 29500 8697.616375237738
# 29750 8681.680671464324
# 30000 8654.003253980052
# Disparate impact (probability of favorable outcome for unprivileged instances / probability of favorable outcome for privileged instances) after LFR with transform threshold = 0.1 = 0.7704886348622849
# --------------Start Fitting Model--------------
# [WARNING] [2019-12-08 20:44:12,912:EnsembleBuilder(1):0423f1b711d209af022cdd3343908c04] No models better than random - using Dummy Score!
# [WARNING] [2019-12-08 20:44:12,925:EnsembleBuilder(1):0423f1b711d209af022cdd3343908c04] No models better than random - using Dummy Score!
# [WARNING] [2019-12-08 20:44:22,359:smac.intensification.intensification.Intensifier] Challenger was the same as the current incumbent; Skipping challenger
# [WARNING] [2019-12-08 20:44:22,359:smac.intensification.intensification.Intensifier] Challenger was the same as the current incumbent; Skipping challenger
# 1
# ['/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183
# [WARNING] [2019-12-08 20:50:14,432:EnsembleBuilder(1):12d4af9c028c86dfb850dc10583e9eb0] No models better than random - using Dummy Score!
# [WARNING] [2019-12-08 20:50:20,191:smac.intensification.intensification.Intensifier] Challenger was the same as the current incumbent; Skipping challenger
# [WARNING] [2019-12-08 20:50:20,191:smac.intensification.intensification.Intensifier] Challenger was the same as the current incumbent; Skipping challenger
# 1
# ['/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_2119/.auto-sklearn/ensembles/1.0000000000.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_2119/.auto-sklearn/ensembles/1.0000000001.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_2119/.auto-sklearn/ensembles/1.0000000002.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_2119/.auto-sklearn/ensembles/1.0000000003.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_2119/.auto-sklearn/ensembles/1.0000000004.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_2119/.auto-sklearn/ensembles/1.0000000005.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_2119/.auto-sklearn/ensembles/1.0000000006.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_2119/.auto-sklearn/ensembles/1.0000000007.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_2119/.auto-sklearn/ensembles/1.0000000008.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_2119/.auto-sklearn/ensembles/1.0000000009.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_2119/.auto-sklearn/ensembles/1.0000000010.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_2119/.auto-sklearn/ensembles/1.0000000011.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_2119/.auto-sklearn/ensembles/1.0000000012.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_2119/.auto-sklearn/ensembles/1.0000000013.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_2119/.auto-sklearn/ensembles/1.0000000014.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_2119/.auto-sklearn/ensembles/1.0000000015.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_2119/.auto-sklearn/ensembles/1.0000000016.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_2119/.auto-sklearn/ensembles/1.0000000017.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_2119/.auto-sklearn/ensembles/1.0000000018.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_2119/.auto-sklearn/ensembles/1.0000000019.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_2119/.auto-sklearn/ensembles/1.0000000020.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_2119/.auto-sklearn/ensembles/1.0000000021.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_2119/.auto-sklearn/ensembles/1.0000000022.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_2119/.auto-sklearn/ensembles/1.0000000023.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_2119/.auto-sklearn/ensembles/1.0000000024.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_2119/.auto-sklearn/ensembles/1.0000000025.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_2119/.auto-sklearn/ensembles/1.0000000026.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_2119/.auto-sklearn/ensembles/1.0000000027.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_2119/.auto-sklearn/ensembles/1.0000000028.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_2119/.auto-sklearn/ensembles/1.0000000029.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_2119/.auto-sklearn/ensembles/1.0000000030.ensemble']
# Best balanced accuracy (after fairness processing) = 0.6409
# Optimal classification threshold (after fairness processing) = 0.5500
#
# 35250 11577.658691204604
# 35500 11361.923252919492
# 35750 10963.933464838443
# 36000 10146.359416616599
# 36250 9616.018299519106
# 36500 9514.563523621315
# 36750 9736.110115383994
# 37000 9293.115061914501
# 37250 9340.888071031997
# 37500 9078.947759815288
# 37750 9065.71025549555
# 38000 8997.22713668266
# 38250 8916.543547829848
# 38500 8885.357540441048
# 38750 8835.508263449034
# 39000 8789.215863817108
# 39250 8736.926849968846
# 39500 8717.931093358506
# 39750 8690.100249748952
# 40000 8661.006186833187
# Disparate impact (probability of favorable outcome for unprivileged instances / probability of favorable outcome for privileged instances) after LFR with transform threshold = 0.5 = 0.3990899664105043
# --------------Start Fitting Model--------------
# [WARNING] [2019-12-08 20:55:09,770:EnsembleBuilder(1):9abf4974c07797d204e9a606c60dbb82] No models better than random - using Dummy Score!
# [WARNING] [2019-12-08 20:55:09,783:EnsembleBuilder(1):9abf4974c07797d204e9a606c60dbb82] No models better than random - using Dummy Score!
# [WARNING] [2019-12-08 20:55:12,812:smac.intensification.intensification.Intensifier] Challenger was the same as the current incumbent; Skipping challenger
# [WARNING] [2019-12-08 20:55:12,812:smac.intensification.intensification.Intensifier] Challenger was the same as the current incumbent; Skipping challenger
# 1
# ['/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_5291/.auto-sklearn/ensembles/1.0000000000.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_5291/.auto-sklearn/ensembles/1.0000000001.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_5291/.auto-sklearn/ensembles/1.0000000002.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_5291/.auto-sklearn/ensembles/1.0000000003.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_5291/.auto-sklearn/ensembles/1.0000000004.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_5291/.auto-sklearn/ensembles/1.0000000005.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_5291/.auto-sklearn/ensembles/1.0000000006.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_5291/.auto-sklearn/ensembles/1.0000000007.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_5291/.auto-sklearn/ensembles/1.0000000008.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_5291/.auto-sklearn/ensembles/1.0000000009.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_5291/.auto-sklearn/ensembles/1.0000000010.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_5291/.auto-sklearn/ensembles/1.0000000011.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_5291/.auto-sklearn/ensembles/1.0000000012.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_5291/.auto-sklearn/ensembles/1.0000000013.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_5291/.auto-sklearn/ensembles/1.0000000014.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_5291/.auto-sklearn/ensembles/1.0000000015.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_5291/.auto-sklearn/ensembles/1.0000000016.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_5291/.auto-sklearn/ensembles/1.0000000017.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_5291/.auto-sklearn/ensembles/1.0000000018.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_5291/.auto-sklearn/ensembles/1.0000000019.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_5291/.auto-sklearn/ensembles/1.0000000020.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_5291/.auto-sklearn/ensembles/1.0000000021.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_5291/.auto-sklearn/ensembles/1.0000000022.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_5291/.auto-sklearn/ensembles/1.0000000023.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_5291/.auto-sklearn/ensembles/1.0000000024.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_5291/.auto-sklearn/ensembles/1.0000000025.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_5291/.auto-sklearn/ensembles/1.0000000026.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_5291/.auto-sklearn/ensembles/1.0000000027.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_5291/.auto-sklearn/ensembles/1.0000000028.ensemble']
# Best balanced accuracy (after fairness processing) = 0.5122
# Optimal classification threshold (after fairness processing) = 0.1300
#
# 40250 13431.719912976321
# 40500 11791.19577679042
# 40750 11231.685470512872
# 41000 14518.67769616328
# 41250 10807.009578380928
# 41500 10379.96553767256
# 41750 9997.394738883935
# 42000 10078.858234173133
# 42250 9746.995215478273
# 42500 9641.644235606416
# 42750 9670.797032439401
# 43000 9468.648448100348
# 43250 9329.372680392697
# 43500 9021.08402123809
# 43750 8856.910450515057
# 44000 8785.614320968298
# 44250 8707.036593230565
# 44500 8654.283639406014
# 44750 8628.566400664171
# 45000 8624.7140322195
# Disparate impact (probability of favorable outcome for unprivileged instances / probability of favorable outcome for privileged instances) after LFR with transform threshold = 0.7000000000000001 = 0.0
# --------------Start Fitting Model--------------
# [WARNING] [2019-12-08 21:00:00,246:EnsembleBuilder(1):a6d4b8357840f58e691e575d1e8a6ef1] No models better than random - using Dummy Score!
# [WARNING] [2019-12-08 21:00:00,259:EnsembleBuilder(1):a6d4b8357840f58e691e575d1e8a6ef1] No models better than random - using Dummy Score!
# [WARNING] [2019-12-08 21:00:03,171:smac.intensification.intensification.Intensifier] Challenger was the same as the current incumbent; Skipping challenger
# [WARNING] [2019-12-08 21:00:03,171:smac.intensification.intensification.Intensifier] Challenger was the same as the current incumbent; Skipping challenger
# 1
# ['/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_2642/.auto-sklearn/ensembles/1.0000000000.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_2642/.auto-sklearn/ensembles/1.0000000001.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_2642/.auto-sklearn/ensembles/1.0000000002.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_2642/.auto-sklearn/ensembles/1.0000000003.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_2642/.auto-sklearn/ensembles/1.0000000004.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_2642/.auto-sklearn/ensembles/1.0000000005.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_2642/.auto-sklearn/ensembles/1.0000000006.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_2642/.auto-sklearn/ensembles/1.0000000007.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_2642/.auto-sklearn/ensembles/1.0000000008.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_2642/.auto-sklearn/ensembles/1.0000000009.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_2642/.auto-sklearn/ensembles/1.0000000010.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_2642/.auto-sklearn/ensembles/1.0000000011.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_2642/.auto-sklearn/ensembles/1.0000000012.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_2642/.auto-sklearn/ensembles/1.0000000013.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_2642/.auto-sklearn/ensembles/1.0000000014.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_2642/.auto-sklearn/ensembles/1.0000000015.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_2642/.auto-sklearn/ensembles/1.0000000016.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_2642/.auto-sklearn/ensembles/1.0000000017.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_2642/.auto-sklearn/ensembles/1.0000000018.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_2642/.auto-sklearn/ensembles/1.0000000019.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_2642/.auto-sklearn/ensembles/1.0000000020.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_2642/.auto-sklearn/ensembles/1.0000000021.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_2642/.auto-sklearn/ensembles/1.0000000022.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_2642/.auto-sklearn/ensembles/1.0000000023.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_2642/.auto-sklearn/ensembles/1.0000000024.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_2642/.auto-sklearn/ensembles/1.0000000025.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_2642/.auto-sklearn/ensembles/1.0000000026.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_2642/.auto-sklearn/ensembles/1.0000000027.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_2642/.auto-sklearn/ensembles/1.0000000028.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_2642/.auto-sklearn/ensembles/1.0000000029.ensemble']
# Best balanced accuracy (after fairness processing) = 0.5271
# Optimal classification threshold (after fairness processing) = 0.0500
#
# 45250 14257.3826469354
# 45500 11332.496316147039
# 45750 11160.835099492799
# 46000 10432.60274152859
# 46250 10106.631044131977
# 46500 9949.630628643257
# 46750 9763.5529186727
# 47000 9309.652774936476
# 47250 9160.999709173298
# 47500 8986.10835613919
# 47750 8897.508364367075
# 48000 8813.15029869173
# 48250 8721.993214801138
# 48500 8671.87495114259
# 48750 8660.914673039748
# 49000 8629.223744494242
# 49250 8606.064349704648
# 49500 8597.284026276788
# 49750 8586.746281505308
# 50000 8573.573016686874
# Disparate impact (probability of favorable outcome for unprivileged instances / probability of favorable outcome for privileged instances) after LFR with transform threshold = 0.9 = nan
# --------------Start Fitting Model--------------
# [WARNING] [2019-12-08 21:04:57,061:EnsembleBuilder(1):500c342f8a4332bdce7a26709d79b43b] No models better than random - using Dummy Score!
# [WARNING] [2019-12-08 21:04:57,074:EnsembleBuilder(1):500c342f8a4332bdce7a26709d79b43b] No models better than random - using Dummy Score!
# [WARNING] [2019-12-08 21:04:59,081:EnsembleBuilder(1):500c342f8a4332bdce7a26709d79b43b] No models better than random - using Dummy Score!
ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_5349/.auto-sklearn/ensembles/1.0000000016.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_5349/.auto-sklearn/ensembles/1.0000000017.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_5349/.auto-sklearn/ensembles/1.0000000018.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_5349/.auto-sklearn/ensembles/1.0000000019.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_5349/.auto-sklearn/ensembles/1.0000000020.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_5349/.auto-sklearn/ensembles/1.0000000021.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_5349/.auto-sklearn/ensembles/1.0000000022.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_5349/.auto-sklearn/ensembles/1.0000000023.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_5349/.auto-sklearn/ensembles/1.0000000024.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_5349/.auto-sklearn/ensembles/1.0000000025.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_5349/.auto-sklearn/ensembles/1.0000000026.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_5349/.auto-sklearn/ensembles/1.0000000027.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_5349/.auto-sklearn/ensembles/1.0000000028.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_5349/.auto-sklearn/ensembles/1.0000000029.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_5349/.auto-sklearn/ensembles/1.0000000030.ensemble', '/var/folders/g8/7zwvds492n5_mj6xqxhxmv500000gn/T/autosklearn_tmp_6183_5349/.auto-sklearn/ensembles/1.0000000031.ensemble', '/var/folders/g8/7zwvds492n5_mj ...
# Best balanced accuracy (after fairness processing) = 0.5000
# Optimal classification threshold (after fairness processing) = 0.0100

# %%
fig = model.plot()
fig

# %%
print(model.preproc_name)
print('Best classification threshold: {}'.format(model.best_ultimate_thres))
print('Best balanced accuracy: {}'.format(model.best_acc))
# Out:
# LFR with transform threshold = 0.1
# Best classification threshold: 0.6900000000000001
# Best balanced accuracy: 0.6873131088204163

# %%
metrics = model.evaluate(test)
# Out:
# Balanced accuracy = 0.6973
# Statistical parity difference = -0.0594
# Mean difference = -0.0594
# Disparate impact = 0.8489
# Average odds difference = -0.0278
# Equal opportunity difference = -0.0422
# Theil index = 0.1321
# Optimal classification threshold (after fairness processing) = 0.3700
#    Balanced accuracy  Statistical parity difference  Mean difference  \
# 0           0.697252                      -0.059351        -0.059351
#
#    Disparate impact  Average odds difference  Equal opportunity difference  \
# 0          0.848895                -0.027797                     -0.042237
#
#    Theil index
# 0     0.132081

# %%
x = np.arange(3)
y = [0.06, 0.12, 0.09]
fig, ax = plt.subplots()
for i, v in enumerate(y):
    ax.text(i-0.1, 
              y[i], 
              y[i], 
              fontsize=11, 
              color='b')
plt.bar(x,y, color='lightblue')
plt.xlabel('Preprocessing Method for Adult Data')
plt.ylabel('ABS(Mean Diff)')
plt.axhline(y=0.14, color='red', linestyle='-')
plt.annotate('0.14', (0.9,0.142),color = 'red')
plt.xticks(x, ('Optim','DIR', 'LFR'))
plt.ylim((0, 0.15))
plt.show()

# %%
x = np.arange(3)
y = [0.85, 0.83, 0.84]
fig, ax = plt.subplots()
for i, v in enumerate(y):
    ax.text(i-0.1, 
              y[i], 
              y[i], 
              fontsize=11, 
              color='b')
plt.bar(x,y, color='lightblue')
plt.xlabel('Preprocessing Method for Adult Data')
plt.ylabel('Disparate impact')
plt.axhline(y=0.62, color='red', linestyle='-')
plt.annotate('0.62', (0.9,0.65),color = 'red')
plt.xticks(x, ('Optim','DIR', 'LFR'))
plt.ylim((0, 1))
plt.show()
